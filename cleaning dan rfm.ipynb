# %% [markdown]
# # Import Library dan Datset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
#Impor Data Ritel Online yang berisi transaksi dari 12/01/2010 dan 12/09/2011
df = pd.read_excel('rfm_dataset.xlsx')
df.head()
# Out:
#         DATE                                 CUSTOMER BR/BKJ  RASPBERRY  \
# 0 2023-11-01  PT. Graha Alam Lestari Pastry po 132401     BR     2000.0
# 1 2023-11-01  PT. Graha Alam Lestari Pastry po 132401     BR        NaN
# 2 2023-11-01   PT. Graha Alam Lestari Koral po 132401     BR      500.0
# 3 2023-11-01                               Melia Bali     BR     2000.0
# 4 2023-11-01                                    Folie     BR      500.0
#
#    BLUEBERRY  FROZEN RASPBERRY  CAPE GOOSEBERRY  TEA  JAM  NO NOTA  \
# 0        NaN               NaN              NaN  NaN  NaN  16914.0
# 1      750.0               NaN              NaN  NaN  NaN  16914.0
# 2        NaN               NaN              NaN  NaN  NaN  16915.0
# 3        NaN               NaN              NaN  NaN  NaN  16916.0
# 4        NaN               NaN              NaN  NaN  NaN  16917.0
#
#    PRICE '/GRS  TOTAL HARGA
# 0          440       880000
# 1          550       412500
# 2          440       220000
# 3          440       880000
# 4          440       220000

# %% [markdown]
# # Cleaning Dataset

# %%
#Melakukan pengecekan shape (columns and rows) dari dataset
df.shape
# Out:
# (346, 12)

# %%
#Check missing value pada dataset
df.isnull().sum(axis=0)
# Out:
# DATE                  0
# CUSTOMER              0
# BR/BKJ                0
# RASPBERRY            31
# BLUEBERRY           344
# FROZEN RASPBERRY    339
# CAPE GOOSEBERRY     325
# TEA                 345
# JAM                 346
# NO NOTA               9
# PRICE '/GRS           0
# TOTAL HARGA           0
# dtype: int64

# %%
df['RASPBERRY'].fillna(0, inplace=True)
df['BLUEBERRY'].fillna(0, inplace=True)
df['FROZEN RASPBERRY'].fillna(0, inplace=True)
df['CAPE GOOSEBERRY'].fillna(0, inplace=True)
df['TEA'].fillna(0, inplace=True)
df['JAM'].fillna(0, inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12912\175551796.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['RASPBERRY'].fillna(0, inplace=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_12912\175551796.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['BLUEBERRY'].fillna(0, inplace=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_12912\175551796.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['FROZEN RASPBERRY'].fillna(0, inplace=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_12912\175551796.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['CAPE GOOSEBERRY'].fillna(0, inplace=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_12912\175551796.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['TEA'].fillna(0, inplace=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_12912\175551796.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['JAM'].fillna(0, inplace=True)

# %%
df.isnull().sum(axis=0)
# Out:
# DATE                0
# CUSTOMER            0
# BR/BKJ              0
# RASPBERRY           0
# BLUEBERRY           0
# FROZEN RASPBERRY    0
# CAPE GOOSEBERRY     0
# TEA                 0
# JAM                 0
# NO NOTA             9
# PRICE '/GRS         0
# TOTAL HARGA         0
# dtype: int64

# %%
df = df.dropna(subset=['NO NOTA'])

# %%
df.shape
# Out:
# (337, 12)

# %%
df.isnull().sum(axis=0)
# Out:
# DATE                0
# CUSTOMER            0
# BR/BKJ              0
# RASPBERRY           0
# BLUEBERRY           0
# FROZEN RASPBERRY    0
# CAPE GOOSEBERRY     0
# TEA                 0
# JAM                 0
# NO NOTA             0
# PRICE '/GRS         0
# TOTAL HARGA         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 337 entries, 0 to 345
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DATE              337 non-null    datetime64[ns]
#  1   CUSTOMER          337 non-null    object
#  2   BR/BKJ            337 non-null    object
#  3   RASPBERRY         337 non-null    float64
#  4   BLUEBERRY         337 non-null    float64
#  5   FROZEN RASPBERRY  337 non-null    float64
#  6   CAPE GOOSEBERRY   337 non-null    float64
#  7   TEA               337 non-null    float64
#  8   JAM               337 non-null    float64
#  9   NO NOTA           337 non-null    float64
#  10  PRICE '/GRS       337 non-null    int64
#  11  TOTAL HARGA       337 non-null    int64
# dtypes: datetime64[ns](1), float64(7), int64(2), object(2)
# memory usage: 34.2+ KB

# %% [markdown]
# # RFM Modelling

# %% [markdown]
# - Recency = Latest Date - Last Inovice Data
# - Frequency = count of invoice no. of transaction(s)
# - Monetary = Sum of Total

# %%
import datetime as dt

# %%
df['DATE'].max()
# Out:
# Timestamp('2023-11-29 00:00:00')

# %%
#Menetapkan tgl terbaru 2023-11-30, hal ini untuk menghitung jumlah hari sejak tanggal invoice terakhir
Latest_Date = dt.datetime(2023,11,30)

# %%
#Membuat RFM Modelling scores untuk setiap customet
rfm_scores = df.groupby('CUSTOMER').agg({
    #Recency
    'DATE': lambda x: (Latest_Date - x.max()).days,

    #Frequency
    'NO NOTA': lambda x: len(x),

    #Monetary
    'TOTAL HARGA': lambda x: x.sum()
})

# %%
rfm_scores.head()
# Out:
#                               DATE  NO NOTA  TOTAL HARGA
# CUSTOMER
# Bintang Hayam Wuruk po 00233    24        2       509000
# Bintang Hayam Wuruk po 01602    17        2       509000
# Bintang Hayam Wuruk po 03293    10        1       425000
# Bintang Hayam Wuruk po 05659     3        1       637500
# Bintang Seminyak                 3        3      1487500

# %%
#Convert data type dari InvoiceDate menjadi int
rfm_scores['DATE'] = rfm_scores['DATE'].astype(int)

# %%
#Rename column pada rfm_scores
rfm_scores.rename(columns={
    'DATE': 'Recency',
    'NO NOTA': 'Frequency',
    'TOTAL HARGA': 'Monetary'
}, inplace=True)

# %%
#Tampilkan dan reset index
rfm_scores.reset_index().head()
# Out:
#                        CUSTOMER  Recency  Frequency  Monetary
# 0  Bintang Hayam Wuruk po 00233       24          2    509000
# 1  Bintang Hayam Wuruk po 01602       17          2    509000
# 2  Bintang Hayam Wuruk po 03293       10          1    425000
# 3  Bintang Hayam Wuruk po 05659        3          1    637500
# 4              Bintang Seminyak        3          3   1487500

# %%
rfm_scores.shape
# Out:
# (202, 3)

# %%
#Split menjadi empat segmen menggunakan kuartil
split = rfm_scores.quantile(q=[0.25,0.5,0.75])
split = split.to_dict()

# %%
split
# Out:
# {'Recency': {0.25: 5.0, 0.5: 13.0, 0.75: 22.0},
#  'Frequency': {0.25: 1.0, 0.5: 1.0, 0.75: 2.0},
#  'Monetary': {0.25: 425000.0, 0.5: 440000.0, 0.75: 831875.0}}

# %%
#Fungsi untuk membuat R, F and M segments

#Recency
def RScoring(x,p,d):
    if x <= d[p][0.25]:
        return 1
    elif x <= d[p][0.50]:
        return 2
    elif x <= d[p][0.75]: 
        return 3
    else:
        return 4

#Frequency  
def FScoring(x,p,d):
    if x <= d[p][0.25]:
        return 4
    elif x <= d[p][0.50]:
        return 3
    elif x <= d[p][0.75]: 
        return 2
    else:
        return 1

#Monetary 
def MScoring(x,p,d):
    if x <= d[p][0.25]:
        return 4
    elif x <= d[p][0.50]:
        return 3
    elif x <= d[p][0.75]: 
        return 2
    else:
        return 1

# %%
#Hitung & Tambahkan kolom nilai segmen R, F dan M di kumpulan data yang ada untuk menampilkan nilai segmen R, F dan M
rfm_scores['R'] = rfm_scores['Recency'].apply(RScoring, args=('Recency',split,))
rfm_scores['F'] = rfm_scores['Frequency'].apply(FScoring, args=('Frequency',split,))
rfm_scores['M'] = rfm_scores['Monetary'].apply(MScoring, args=('Monetary',split,))
rfm_scores.head()
# Out:
#                               Recency  Frequency  Monetary  R  F  M
# CUSTOMER
# Bintang Hayam Wuruk po 00233       24          2    509000  4  2  2
# Bintang Hayam Wuruk po 01602       17          2    509000  3  2  2
# Bintang Hayam Wuruk po 03293       10          1    425000  2  4  4
# Bintang Hayam Wuruk po 05659        3          1    637500  1  4  2
# Bintang Seminyak                    3          3   1487500  1  1  1

# %%
#Hitung dan tambahkan pada column baru RFMGroup untuk melihat kombinasi dari rfm score
rfm_scores['RFMGroup'] = rfm_scores.R.map(str) + rfm_scores.F.map(str) + rfm_scores.M.map(str)

# %%
rfm_scores.head()
# Out:
#                               Recency  Frequency  Monetary  R  F  M RFMGroup
# CUSTOMER
# Bintang Hayam Wuruk po 00233       24          2    509000  4  2  2      422
# Bintang Hayam Wuruk po 01602       17          2    509000  3  2  2      322
# Bintang Hayam Wuruk po 03293       10          1    425000  2  4  4      244
# Bintang Hayam Wuruk po 05659        3          1    637500  1  4  2      142
# Bintang Seminyak                    3          3   1487500  1  1  1      111

# %%
#Hitung dan tambahkan pada column baru RFMScore untuk menampilkan total sum dari RFMGroup values
rfm_scores['RFMScore'] = rfm_scores[['R', 'F', 'M']].sum(axis=1)
rfm_scores.head()
# Out:
#                               Recency  Frequency  Monetary  R  F  M RFMGroup  \
# CUSTOMER
# Bintang Hayam Wuruk po 00233       24          2    509000  4  2  2      422
# Bintang Hayam Wuruk po 01602       17          2    509000  3  2  2      322
# Bintang Hayam Wuruk po 03293       10          1    425000  2  4  4      244
# Bintang Hayam Wuruk po 05659        3          1    637500  1  4  2      142
# Bintang Seminyak                    3          3   1487500  1  1  1      111
#
#                               RFMScore
# CUSTOMER
# Bintang Hayam Wuruk po 00233         8
# Bintang Hayam Wuruk po 01602         7
# Bintang Hayam Wuruk po 03293        10
# Bintang Hayam Wuruk po 05659         7
# Bintang Seminyak                     3

# %%
# RFMScore 1 diberikan Single-time
# RFMScore 2-4 diberikan Occasional
# RFMScore 5-9 diberikan Potential
# RFMScore 10-12 diberikan Loyal

# Menetapkan batas untuk kategori RFMScore
bins = [0, 1, 5, 10, 12]
# Menetapkan label untuk masing-masing kategori
labels = ['Single-time', 'Occasional', 'Potential', 'Loyal']

# Menetapkan Loyalty Level untuk setiap customer berdasarkan RFMScore
rfm_scores['RFM_Loyalty_Level'] = pd.cut(rfm_scores['RFMScore'], bins=bins, labels=labels, right=False)

# Menampilkan hasil
rfm_scores.reset_index().head()


# #Menetapkan Loyalty Level untuk masing-masing customer
# Loyalty_Level = ['Single-time', 'Occasional', 'Potential', 'Loyal']
# Score_cuts = pd.qcut(rfm_scores.RFMScore, q = 4, labels = Loyalty_Level)
# rfm_scores['RFM_Loyalty_Level'] = Score_cuts.values
# rfm_scores.reset_index().head()
# Out:
#                        CUSTOMER  Recency  Frequency  Monetary  R  F  M  \
# 0  Bintang Hayam Wuruk po 00233       24          2    509000  4  2  2
# 1  Bintang Hayam Wuruk po 01602       17          2    509000  3  2  2
# 2  Bintang Hayam Wuruk po 03293       10          1    425000  2  4  4
# 3  Bintang Hayam Wuruk po 05659        3          1    637500  1  4  2
# 4              Bintang Seminyak        3          3   1487500  1  1  1
#
#   RFMGroup  RFMScore RFM_Loyalty_Level
# 0      422         8         Potential
# 1      322         7         Potential
# 2      244        10             Loyal
# 3      142         7         Potential
# 4      111         3        Occasional

# %%
#Validate the data for RFMGroup = 444 adalah loyal
loyal=rfm_scores[rfm_scores['RFM_Loyalty_Level']=='Loyal'].sort_values('Monetary', ascending=False).reset_index().head(30)
loyal
# Out:
#                            CUSTOMER  Recency  Frequency  Monetary  R  F  M  \
# 0            COD - Ruster (grade B)       29          1    600000  4  4  2
# 1           COD - Frencha - uluwatu       27          1    600000  4  4  2
# 2          The Mulia Pastry po31542       17          1    440000  3  4  3
# 3                 Bulgary po 178882       29          1    440000  4  4  3
# 4      The Mulia Commisary po 30226       29          1    440000  4  4  3
# 5      The Mulia Commisary po 30496       27          1    440000  4  4  3
# 6      The Mulia Commisary po 30756       24          1    440000  4  4  3
# 7              Hyatt Andaz po 31937       17          1    440000  3  4  3
# 8              Hyatt Andaz po 31668       24          1    440000  4  4  3
# 9      The Mulia Commisary po 31441       20          1    440000  3  4  3
# 10     The Mulia Commisary po 31972       15          1    440000  3  4  3
# 11           Four Seasons po 214965       29          1    440000  4  4  3
# 12        The Mulia Pastry po 30175       29          1    440000  4  4  3
# 13                 Conrad po 193216       17          1    440000  3  4  3
# 14     The Mulia Commisary po 31576       17          1    440000  3  4  3
# 15        The Mulia Pastry po 30480       27          1    440000  4  4  3
# 16        The Mulia Pastry po 31915       15          1    440000  3  4  3
# 17  COD - Leszek Slawomir (Zukabar)       27          1    440000  4  4  3
# 18         COD - Kanvaz PO-23-02414       17          1    440000  3  4  3
# 19          COD - Jumeirah po 27155       17          1    440000  3  4  3
# 20          COD - Jumeirah po 27085       24          1    440000  4  4  3
# 21               COD - 07 am Bakers       20          1    440000  3  4  3
# 22                Bulgary po 179759       15          1    440000  3  4  3
# 23        The Mulia Pastry po 30720       24          1    440000  4  4  3
# 24         The Mulia Pastry po31383       20          1    440000  3  4  3
# 25                    COD - Indigo        17          1    435000  3  4  3
# 26               Pepito Semer 25738       15          1    425000  3  4  4
# 27         Pepito Nusa Dua po 20217       15          1    425000  3  4  4
# 28         Pepito Nusa Dua po 20730       10          1    425000  2  4  4
# 29        Pepito Pererenan po 24471       20          1    425000  3  4  4
#
#    RFMGroup  RFMScore RFM_Loyalty_Level
# 0       442        10             Loyal
# 1       442        10             Loyal
# 2       343        10             Loyal
# 3       443        11             Loyal
# 4       443        11             Loyal
# 5       443        11             Loyal
# 6       443        11             Loyal
# 7       343        10             Loyal
# 8       443        11             Loyal
# 9       343        10             Loyal
# 10      343        10             Loyal
# 11      443        11             Loyal
# 12      443        11             Loyal
# 13      343        10             Loyal
# 14      343        10             Loyal
# 15      443        11             Loyal
# 16      343        10             Loyal
# 17      443        11             Loyal
# 18      343        10             Loyal
# 19      343        10             Loyal
# 20      443        11             Loyal
# 21      343        10             Loyal
# 22      343        10             Loyal
# 23      443        11             Loyal
# 24      343        10             Loyal
# 25      343        10             Loyal
# 26      344        11             Loyal
# 27      344        11             Loyal
# 28      244        10             Loyal
# 29      344        11             Loyal

# %%
#Validate the data for RFMGroup = 444 adalah loyal
potential=rfm_scores[rfm_scores['RFM_Loyalty_Level']=='Potential'].sort_values('Monetary', ascending=False).reset_index().head(30)
potential
# Out:
#                                    CUSTOMER  Recency  Frequency  Monetary  R  \
# 0              The Mulia Commisary po 32947        6          1   1320000  2
# 1                              COD - Cocoku       19          2   1320000  3
# 2   PT. Graha Alam Lestari Pastry po 132401       29          2   1292500  4
# 3                              COD - Indigo       10          2   1160000  2
# 4               The Mulia Commisary po33105        3          1   1100000  1
# 5   PT. Graha Alam Lestari Pastry po 134890        6          1   1100000  2
# 6                         Pepito Echo Beach        6          2   1062500  2
# 7                       COD - Wood/ pick up       29          2    990000  4
# 8                            Papaya po 0183       22          2    985000  3
# 9                     Bintang Ubud po 01071       19          2    917500  3
# 10  PT. Graha Alam Lestari Pastry po 134887        8          1    880000  2
# 11  PT. Graha Alam Lestari Pastry po 134861       10          1    880000  2
# 12  PT. Graha Alam Lestari Pastry po 134124       13          1    880000  2
# 13  PT. Graha Alam Lestari Pastry po 134118       15          1    880000  3
# 14  PT. Graha Alam Lestari Pastry po 133381       22          1    880000  3
# 15  PT. Graha Alam Lestari Pastry po 133270       24          1    880000  4
# 16  PT. Graha Alam Lestari Pastry po 132404       27          1    880000  4
# 17  PT. Graha Alam Lestari Pastry po 135551        3          1    880000  1
# 18  PT. Graha Alam Lestari Pastry po 134086       17          1    880000  3
# 19  PT. Graha Alam Lestari Pastry po 135646        1          1    880000  1
# 20         St. Regis po 86848 (harus dapat)        1          1    880000  1
# 21                         Pepito Eco Beach       20          2    850000  3
# 22               Pepito Tebongkang po 31038       19          2    777500  3
# 23                          COD - Mamu Cafe        5          2    770000  1
# 24                    Pepito Semer po 24199       29          2    675000  4
# 25               PT Sumber Agri Sehat Brawa       15          1    675000  3
# 26        PT. Sumber Agri Sehat Batu bolong       15          1    675000  3
# 27                The Mulia Pastry po 33075        3          1    660000  1
# 28                The Mulia Pastry po 32931        6          1    660000  2
# 29             The Mulia Commisary po 33516        1          1    660000  1
#
#     F  M RFMGroup  RFMScore RFM_Loyalty_Level
# 0   4  1      241         7         Potential
# 1   2  1      321         6         Potential
# 2   2  1      421         7         Potential
# 3   2  1      221         5         Potential
# 4   4  1      141         6         Potential
# 5   4  1      241         7         Potential
# 6   2  1      221         5         Potential
# 7   2  1      421         7         Potential
# 8   2  1      321         6         Potential
# 9   2  1      321         6         Potential
# 10  4  1      241         7         Potential
# 11  4  1      241         7         Potential
# 12  4  1      241         7         Potential
# 13  4  1      341         8         Potential
# 14  4  1      341         8         Potential
# 15  4  1      441         9         Potential
# 16  4  1      441         9         Potential
# 17  4  1      141         6         Potential
# 18  4  1      341         8         Potential
# 19  4  1      141         6         Potential
# 20  4  1      141         6         Potential
# 21  2  1      321         6         Potential
# 22  2  2      322         7         Potential
# 23  2  2      122         5         Potential
# 24  2  2      422         8         Potential
# 25  4  2      342         9         Potential
# 26  4  2      342         9         Potential
# 27  4  2      142         7         Potential
# 28  4  2      242         8         Potential
# 29  4  2      142         7         Potential

# %%
#Validate the data for RFMGroup = 444 adalah loyal
occasional=rfm_scores[rfm_scores['RFM_Loyalty_Level']=='Occasional'].sort_values('Monetary', ascending=False).reset_index().head(30)
occasional
# Out:
#                              CUSTOMER  Recency  Frequency  Monetary  R  F  M  \
# 0                          Melia Bali        1         13  11440000  1  1  1
# 1                         COD - Alive        1          6   5510000  1  1  1
# 2                     COD - Butterman        1         10   4180000  1  1  1
# 3                      Canggu Station        1          5   2709375  1  1  1
# 4                          Pepito SWJ        1          5   2443750  1  1  1
# 5                     Pepito Peliatan        5          4   2443750  1  1  1
# 6                          COD - Usha        3          6   2310000  1  1  1
# 7                               Delta        5          4   2178125  1  1  1
# 8                        Popular Deli        1          5   2125000  1  1  1
# 9                       Pepito Andong        5          4   2125000  1  1  1
# 10                     Pepito Uluwatu        1          4   2018750  1  1  1
# 11    PT. Sumber Agri Sehat Pererenan       13          4   1945000  2  1  1
# 12     PT. Sumber Agri Sehat Seminyak        3          4   1940125  1  1  1
# 13    PT. Sumber Agri Sehat Kerobokan        6          4   1858750  2  1  1
# 14                       Bintang Ubud        5          3   1806250  1  1  1
# 15                  Pepito Tebongkang        5          3   1806250  1  1  1
# 16                 Grand Lucky Sunset        1          3   1700000  1  1  1
# 17                         COD - Wood        6          4   1650000  2  1  1
# 18                         COD - Fold        6          4   1540000  2  1  1
# 19                             Papaya        8          3   1487500  2  1  1
# 20                   Bintang Seminyak        3          3   1487500  1  1  1
# 21                              Folie        3          6   1320000  1  1  1
# 22           COD - Dennis/ tanpa nota        1          5   1320000  1  1  1
# 23        PT. Sumber Agri Sehat Brawa        8          3   1296250  2  1  1
# 24                  Grand Lucky Sanur       10          3   1275000  2  1  1
# 25  PT. Sumber Agri Sehat Batu Bolong        6          3   1240000  2  1  1
# 26                        COD - Paula        3          4   1210000  1  1  1
# 27                         COD - Zest        5          4    990000  1  1  1
# 28                       COD - Redgun        6          4    880000  2  1  1
# 29                      COD - Capella        5          3    660000  1  1  2
#
#    RFMGroup  RFMScore RFM_Loyalty_Level
# 0       111         3        Occasional
# 1       111         3        Occasional
# 2       111         3        Occasional
# 3       111         3        Occasional
# 4       111         3        Occasional
# 5       111         3        Occasional
# 6       111         3        Occasional
# 7       111         3        Occasional
# 8       111         3        Occasional
# 9       111         3        Occasional
# 10      111         3        Occasional
# 11      211         4        Occasional
# 12      111         3        Occasional
# 13      211         4        Occasional
# 14      111         3        Occasional
# 15      111         3        Occasional
# 16      111         3        Occasional
# 17      211         4        Occasional
# 18      211         4        Occasional
# 19      211         4        Occasional
# 20      111         3        Occasional
# 21      111         3        Occasional
# 22      111         3        Occasional
# 23      211         4        Occasional
# 24      211         4        Occasional
# 25      211         4        Occasional
# 26      111         3        Occasional
# 27      111         3        Occasional
# 28      211         4        Occasional
# 29      112         4        Occasional

# %%
#Validate the data for RFMGroup = 444 adalah loyal
single_time=rfm_scores[rfm_scores['RFM_Loyalty_Level']=='Single-time'].sort_values('Monetary', ascending=False).reset_index().head(30)
single_time
# Out:
# Empty DataFrame
# Columns: [CUSTOMER, Recency, Frequency, Monetary, R, F, M, RFMGroup, RFMScore, RFM_Loyalty_Level]
# Index: []

# %%
with pd.ExcelWriter('output.xlsx') as writer:
    # Membuat DataFrame baru untuk setiap kategori
    for category in rfm_scores['RFM_Loyalty_Level'].unique():
        category_data = rfm_scores[rfm_scores['RFM_Loyalty_Level'] == category]
        # Menyimpan DataFrame ke sheet yang sesuai dengan kategorinya
        category_data.to_excel(writer, sheet_name=category, index=False)

# %%
rfm_scores.shape
# Out:
# (202, 11)

# %%
with pd.ExcelWriter('rfm_output.xlsx') as writer:
    # Membuat DataFrame baru untuk setiap kategori
    for category in rfm_scores['RFM_Loyalty_Level'].unique():
        category_data = rfm_scores[rfm_scores['RFM_Loyalty_Level'] == category]
        # Menyimpan DataFrame ke sheet yang sesuai dengan kategorinya
        category_data.to_excel(writer, sheet_name=category)
